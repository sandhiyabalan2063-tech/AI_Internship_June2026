# %%
name="sandhiya"
department="computer science"
age=19
salary=300000
print(name)
print(department)
print(age)
print(salary)
# Out:
# sandhiya
# computer science
# 19
# 300000

# %%
#bill calculation
rice=90
milk=20
oil=30
sugar=5
tea=6
print("total  = ",rice+milk+oil+sugar+tea)
# Out:
# total  =  151

# %%
#student percentage
tamil=80
english=90
maths=89
science=91
social=79
total=tamil+english+maths+science+social
print("percentage=",total/5)
# Out:
# percentage= 85.8

# %%
#mobile recharge calculation
recharge=299
gst=20
gstpercentage=(recharge*gst)/100
finalamount=(recharge+gstpercentage)
print(finalamount)
# Out:
# 358.8
